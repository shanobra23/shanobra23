# %% [markdown]
# # <center> Jeodyshan Obra  </center>

# %% [markdown]
# # <center> IS362 Assignment 12 </center>

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json, requests

# %% [markdown]
# ### First we would need to go into https://developer.nytimes.com/
# #### Then you would search for the available API's then request an API Key

# %% [markdown]
# ### My API Key

# %%
api_key = 'cXG03rSlYVhEFc75qn3iYIuIPyUWrJuk'

# %% [markdown]
# ### Combining my API Key and URL

# %%
url = 'https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?'
myrequest = url + '&api-key=' + api_key

# %% [markdown]
# ### This Load the displays the data.

# %%
mostpopular = json.loads(requests.get(myrequest).text) 
mostpopular
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'uri': 'nyt://article/acd4e395-0b1a-5839-afd5-ad6d502b09a4',
#    'url': 'https://www.nytimes.com/2020/05/02/us/asian-giant-hornet-washington.html',
#    'id': 100000007104409,
#    'asset_id': 100000007104409,
#    'source': 'New York Times',
#    'published_date': '2020-05-02',
#    'updated': '2020-05-08 11:33:56',
#    'section': 'U.S.',
#    'subsection': '',
#    'nytdsection': 'u.s.',
#    'adx_keywords': 'Hornets (Insects);Bees;Invasive Species;British Columbia (Canada);Washington (State)',
#    'column': None,
#    'byline': 'By Mike Baker',
#    'type': 'Article',
#    'title': '‘Murder Hornets’ in the U.S.: The Rush to Stop the Asian Giant Hornet',
#    'abstract': 'Sightings of the Asian giant hornet have prompted fears that the vicious insect could establish itself in the United States and devastate bee populations.',
# ...

# %% [markdown]
# ### This allows the data to be transformed to a more readable format

# %%
transform = json_normalize(mostpopular['results'])
transform
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                                   uri  \
# 0   nyt://article/acd4e395-0b1a-5839-afd5-ad6d502b...
# 1   nyt://article/6da3ed1e-d763-5bb0-b793-f0fd3da8...
# 2   nyt://article/43366b7d-be38-5df5-ac71-21eecf50...
# 3   nyt://article/616344ab-073b-509b-a9f0-8dbe6e63...
# 4   nyt://article/b34d3448-c5bb-5433-9e70-86c057c0...
# 5   nyt://article/ff198a2e-d18d-5ad0-810a-e49cfbe7...
# 6   nyt://article/934bc067-1b36-5640-9d7b-a2fb0a3a...
# 7   nyt://article/097eaa57-7ebd-5ca1-8444-c49d142a...
# 8   nyt://article/262e3b8e-ffd4-5b94-97f0-1731687b...
# 9   nyt://article/0b7803ec-6849-5cb3-88df-49395870...
# 10  nyt://article/77f2c0c1-0d43-5c7c-adc6-dfa17f4a...
# 11  nyt://article/11016234-d255-5681-83c6-586c1924...
# ...

# %% [markdown]
# ### This transform the data based on the displayed columns

# %%
df = transform[['url', 'source','abstract', 'section']]
df
# Out:
#                                                   url          source  \
# 0   https://www.nytimes.com/2020/05/02/us/asian-gi...  New York Times
# 1   https://www.nytimes.com/2020/05/02/opinion/sun...  New York Times
# 2   https://www.nytimes.com/2020/05/04/us/coronavi...  New York Times
# 3   https://www.nytimes.com/2020/05/05/nyregion/ch...  New York Times
# 4   https://www.nytimes.com/2020/05/03/opinion/dav...  New York Times
# 5   https://www.nytimes.com/2020/05/06/opinion/ahm...  New York Times
# 6   https://www.nytimes.com/2020/05/01/health/coro...  New York Times
# 7   https://www.nytimes.com/2020/05/03/world/asia/...  New York Times
# 8   https://www.nytimes.com/2020/05/06/science/lla...  New York Times
# 9   https://www.nytimes.com/2020/05/01/world/asia/...  New York Times
# 10  https://www.nytimes.com/2020/05/03/us/politics...  New York Times
# 11  https://www.nytimes.com/2020/05/01/us/politics...  New York Times
# ...
