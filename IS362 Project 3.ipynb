# %% [markdown]
# # <center> Jeodyshan Obra </center>

# %% [markdown]
# # <center> IS362 Project 3 </center>

# %%
import  pandas as pd
import sqlite3

# %% [markdown]
# ##### I am connecting the Chinnok_sqlite file using the connect()

# %%
con = sqlite3.connect("Chinook_Sqlite.sqlite")
tracks = pd.read_sql_query("SELECT * from Track", con=con)

# %% [markdown]
# ### This is the entire track query

# %%
tracks
# Out:
#       TrackId                                               Name  AlbumId  \
# 0           1            For Those About To Rock (We Salute You)        1
# 1           2                                  Balls to the Wall        2
# 2           3                                    Fast As a Shark        3
# 3           4                                  Restless and Wild        3
# 4           5                               Princess of the Dawn        3
# ...       ...                                                ...      ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...      343
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...      344
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)      345
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...      346
# 3502     3503                                      Koyaanisqatsi      347
#
#       MediaTypeId  GenreId                                           Composer  \
# ...

# %% [markdown]
# ##### This SQL query will join all five tables and sort them by Last and First Name

# %%
sql = '''SELECT name.LastName, name.FirstName, track.Name, alb.Title
         FROM Customer as name
         LEFT JOIN Invoice as invo
         ON name.CustomerId = invo.CustomerId
         LEFT JOIN InvoiceLine as involine
         ON invo.InvoiceId = involine.InvoiceId
         LEFT JOIN Track as track
         ON involine.TrackId = track.TrackId
         LEFT JOIN Album as alb
         ON track.AlbumId = alb.AlbumId
         ORDER BY name.LastName, name.FirstName'''

con = sqlite3.connect("Chinook_Sqlite.sqlite")
db = pd.read_sql_query(sql , con=con).head(10)
con.close()
db
# Out:
#   LastName FirstName                                               Name  \
# 0  Almeida   Roberto                            Right Next Door to Hell
# 1  Almeida   Roberto                                     In The Evening
# 2  Almeida   Roberto                                   Fool In The Rain
# 3  Almeida   Roberto  Saudade Dos Aviões Da Panair (Conversando No Bar)
# 4  Almeida   Roberto                             Caso Você Queira Saber
# 5  Almeida   Roberto                                              Dance
# 6  Almeida   Roberto                                          Aos Leões
# 7  Almeida   Roberto                                           Demorou!
# 8  Almeida   Roberto                                    Home Sweet Home
# 9  Almeida   Roberto                                              Intro
#
#                                         Title
# 0                         Use Your Illusion I
# 1                     In Through The Out Door
# ...
