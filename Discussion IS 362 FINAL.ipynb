# %% [markdown]
# ###  <center> Jeodyshan Obra </center>
#
# ### <center>IS 362 </center>

# %% [markdown]
# ## Disney+ Recommender System

# %%
from IPython.display import Image
Image('Disney+.png')

# %% [markdown]
# #### This recommender system is very much similar to other streaming services. Disney+ is a multi-platform streaming service that allows users to watch through a paid premium. This services uses a recommender system since it wants to show users similar movies & tv shows to keep the user engaged with the service.

# %% [markdown]
# ## Scenario Design Analysis

# %% [markdown]
# ### What are your target users?

# %% [markdown]
# ###### The Target users are fans who avidly watch all of Disney content put into one streaming service. This could be movies and Tv shows from different studios such as Marvel + Disney + Nat Geo + Fox Studios + Lucas Films + Pixar + Many more! So this targets alot of users depending on what content they desire

# %% [markdown]
# ### What are their key goals?

# %% [markdown]
# ###### The key Goals with Disney+ is to put all of Disney's content that is popular content without paying for many movies and allow user to enjoy a roster of Tv Shows & Movies.

# %% [markdown]
# ### How can you help them accomplish those goals?

# %% [markdown]
# ###### Disney+ accomplishes its goals by a vareity of content for users to watch. So when a user uses the recommender system Disney+ will compare the movie the user is watching and find something similar to it. One example is when a user is watch Marvel's Avengers:Endgame the user will get a recommendation for Marvel's Avengers: Infinity War to watch next. The recommender system can also find similar movies from other studios or based on how frequently the user watches a specifc genre.

# %% [markdown]
# ### Reverse Engineering

# %% [markdown]
# ##### How Disney+ accomplishes this recommender system is it would use the data of the user based on what they watch. Explained earlier they it would give the user a similar movie either from the same studio or from a different studio. As you can see in this example I took. Disney+ recognizes that I have movies & Tv Shows that I still need to continue to watch and they recommended me movies & series since I watched "America's Funniest Home Videos."

# %%
Image('Disney+ recommender.png')

# %% [markdown]
# ### Recommendations

# %% [markdown]
# ##### Disney+ is very similar to other streaming services such as HULU and Netflix. Which recommends content for the user based on past watch history data. This allows the user to always be engaged with the service. However, Disney+ also recommends content based on its popularity and on the top page. With all that data that Disney+ is taking from my watch history it will always recommend the right content whenever I open the service.
