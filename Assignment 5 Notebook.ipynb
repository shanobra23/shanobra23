# %% [markdown]
# # <center> Jeodyshan Obra IS 362 Assignemnt 5 </center>

# %%
import pandas as pd
from pandas import DataFrame
df = pd.read_csv("airports.csv")

# %% [markdown]
# ## Displaying airports data

# %%
pd.read_csv("airports.csv")
# Out:
#       faa                                  name        lat         lon   alt  \
# 0     04G                     Lansdowne Airport  41.130472  -80.619583  1044
# 1     06A         Moton Field Municipal Airport  32.460572  -85.680028   264
# 2     06C                   Schaumburg Regional  41.989341  -88.101243   801
# 3     06N                       Randall Airport  41.431912  -74.391561   523
# 4     09J                 Jekyll Island Airport  31.074472  -81.427778    11
# 5     0A9        Elizabethton Municipal Airport  36.371222  -82.173417  1593
# 6     0G6               Williams County Airport  41.467306  -84.506778   730
# 7     0G7         Finger Lakes Regional Airport  42.883565  -76.781232   492
# 8     0P2          Shoestring Aviation Airfield  39.794824  -76.647191  1000
# 9     0S9                 Jefferson County Intl  48.053809 -122.810644   108
# 10    0W3                Harford County Airport  39.566838  -76.202403   409
# ...

# %%
df.loc[(df['lat'] >= 71)]
# Out:
#      faa                        name        lat         lon  alt  tz dst  \
# 230  BRW  Wiley Post Will Rogers Mem  71.285446 -156.766003   44  -9   A
# 417  EEN     Dillant Hopkins Airport  72.270833   42.898333  149  -5   A
#
#                  tzone
# 230  America/Anchorage
# 417                NaN

# %% [markdown]
# ### By filtering the data 71 latitude is the highest point of Alaska and Wiley Post WIll Rogers is the northernmost airport in America

# %%
df.loc[(df['lon'] >= -68)]
# Out:
#       faa                           name        lat         lon   alt  tz dst  \
# 396   DVT  Deer Valley Municipal Airport  33.411700  112.457000  1478   8   A
# 417   EEN        Dillant Hopkins Airport  72.270833   42.898333   149  -5   A
# 444   EPM     Eastport Municipal Airport  44.910111  -67.012694    45  -5   A
# 624   HUL                   Houlton Intl  46.123083  -67.792056   489  -5   A
# 942   MYF               Montgomery Field  32.475900  117.759000    17   8   A
# 1290  SYA                   Eareckson As  52.712275  174.113620    98  -9   A
#
#                   tzone
# 396      Asia/Chongqing
# 417                 NaN
# 444    America/New_York
# 624    America/New_York
# 942      Asia/Chongqing
# 1290  America/Anchorage

# %% [markdown]
# ### By filtering the data -68 longitude is the easternmost part of the United States. So Houlton Intl Airport is the easternmost airport in America

# %%
dw = pd.read_csv("weather.csv")

# %% [markdown]
# ## Displaying Weather Data

# %%
pd.read_csv("weather.csv")
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     1  39.02  26.06  59.37     270.0
# 1        EWR  2013      1    1     2  39.02  26.96  61.63     250.0
# 2        EWR  2013      1    1     3  39.02  28.04  64.43     240.0
# 3        EWR  2013      1    1     4  39.92  28.04  62.21     250.0
# 4        EWR  2013      1    1     5  39.02  28.04  64.43     260.0
# 5        EWR  2013      1    1     6  37.94  28.04  67.21     240.0
# 6        EWR  2013      1    1     7  39.02  28.04  64.43     240.0
# 7        EWR  2013      1    1     8  39.92  28.04  62.21     250.0
# 8        EWR  2013      1    1     9  39.92  28.04  62.21     260.0
# 9        EWR  2013      1    1    10  41.00  28.04  59.65     260.0
# 10       EWR  2013      1    1    11  41.00  26.96  57.06     260.0
# 11       EWR  2013      1    1    13  39.20  28.40  69.67     330.0
# 12       EWR  2013      1    1    14  39.02  24.08  54.68     280.0
# ...

# %%
dw.loc[(dw['wind_speed'] >= 40)]
# Out:
#       origin  year  month  day  hour   temp   dewp   humid  wind_dir  \
# 722      EWR  2013      1   31     4  60.80  59.00   93.79     230.0
# 724      EWR  2013      1   31     6  57.20  53.60   87.74     270.0
# 1009     EWR  2013      2   12     3  39.02  26.96   61.63     260.0
# 9425     JFK  2013      1   31     4  53.60  53.06  100.00     200.0
# 18131    LGA  2013      1   31     4  59.00  55.40   93.69     230.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# 722      40.27730   58.68978    0.30       NaN    6.0  2013-01-31T09:00:00Z
# 724      42.57886   55.23744    0.03       NaN   10.0  2013-01-31T11:00:00Z
# 1009   1048.36058        NaN    0.00    1008.3   10.0  2013-02-12T08:00:00Z
# 9425     42.57886   52.93588    0.20       NaN    2.0  2013-01-31T09:00:00Z
# 18131    40.27730   55.23744    0.41       NaN    8.0  2013-01-31T09:00:00Z

# %% [markdown]
# ### By filtering the wind_speed column EWR is the most windiest airport within the New York Area at 2013. With 1048 wind_speed.
